# %% [markdown]
# # Mutichannel-multitask model
# Combine all system monitoring conditions together into a multitask learning approach which to apply to both the CNN and the LSTM based network

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from natsort import natsorted
import torch
import torch.nn as nn
from tensorboardX import SummaryWriter

import sys
sys.path.insert(0, "../")
from data_preparation.prepare_data import import_data
from model import make_loaders, CNN, LSTMattn, MultiClassifier, eval_batch

# %% [markdown]
# ### Training routine

# %%
def train_multitask(model, train_loader, test_loader, dir_checkpoint, dir_writer, 
                    epochs=10, batch_size=4, lr=1e-5, save_cp=True, gpu=False):
    
    writer = SummaryWriter(dir_writer)
    
    print(f'''Start training: 
                Epocs = {epochs}
                Batch size = {batch_size}
                Learning rate = {lr} 
                Training size = {train_loader.dataset.__len__()}
                Validation size = {test_loader.dataset.__len__()}
                CUDA = {gpu}
          ''')
   
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)

    for epoch in range(epochs):

        print('Starting epoch {}/{}.'.format(epoch + 1, epochs))
        model.train()
        epoch_loss = 0

        for i, sample_batch in enumerate(train_loader):

            inputs, labels = sample_batch['sequence'], sample_batch['label'] 
            if gpu:
                inputs = inputs.cuda()
                labels = labels.cuda()

            outputs = model(inputs)
            # multi-task loss
            loss = 0
            for lx in range(len(outputs)):
                loss += criterion(outputs[lx], labels[:, lx])
            epoch_loss += loss.item()

            if i%10 == 0:
                print(f'epoch = {epoch+1:d}, iteration = {i:d}/{len(train_loader):d}, loss = {loss.item():.5f}')

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        print(f'Epoch finished ! Loss: {epoch_loss/i}')
        # training set accuracy
        accuracy = eval_batch(model, train_loader, n_labels=len(targets))
        print(f'Accuracy = {accuracy}')
        writer.add_scalars('accuracy', {f'label_{i}':a for i,a in enumerate(accuracy)}, len(train_loader) * (epoch+1))
        
        if save_cp:
            torch.save(model.state_dict(), dir_checkpoint + 'CP{}.pth'.format(epoch + 1))
            print('Checkpoint {} saved !'.format(epoch + 1))

        
    writer.close()

# %% [markdown]
# ### Main

# %%
data_dir = '<path-to-dataset>'
writer_dir = './runs/experiment_1'
checkpoint_dir = './checkpoints/experiment_1/'
os.makedirs(checkpoint_dir)

channels = ['CP', 'FS1', 'PS1', 'PS2', 'PS3', 'PS4', 'PS5', 'SE', 'VS1']
targets = [0,1,2,3]
gpu = False
sequence = 50

print('Preparing data')
data = import_data(data_dir, sequence)
train_loader, test_loader = make_loaders(data, channels, targets)

# CNN model
# model = CNN(sequence, input_dim=len(channels)) 
# LSTM model
model = LSTMattn(len(channels), hidden_dim=20, num_layers=1)
# add multi-task classifier
model.classifier = MultiClassifier(model.classifier.in_features)

if gpu:
    model.cuda()

train_multitask(model, train_loader, test_loader, checkpoint_dir, writer_dir, lr=1e-3 )
accuracy = eval_batch(model, test_loader, n_labels=4)
print(accuracy)
# Out:
# Preparing data
# /Users/francescobattocchio/miniconda3/envs/deep-pdm/lib/python3.7/site-packages/torch/nn/modules/rnn.py:50: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.8 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# Start training:
#                 Epocs = 10
#                 Batch size = 4
#                 Learning rate = 0.001
#                 Training size = 1984
#                 Validation size = 221
#                 CUDA = False
#
# Starting epoch 1/10.
# epoch = 1, iteration = 0/496, loss = 5.10720
# epoch = 1, iteration = 10/496, loss = 4.73586
# epoch = 1, iteration = 20/496, loss = 4.83484
# epoch = 1, iteration = 30/496, loss = 5.03915
# epoch = 1, iteration = 40/496, loss = 4.47967
# epoch = 1, iteration = 50/496, loss = 5.01119
# epoch = 1, iteration = 60/496, loss = 4.71459
# epoch = 1, iteration = 70/496, loss = 4.86597
# epoch = 1, iteration = 80/496, loss = 4.30579
# epoch = 1, iteration = 90/496, loss = 4.11236
# epoch = 1, iteration = 100/496, loss = 4.56768
# epoch = 1, iteration = 110/496, loss = 4.49729
# epoch = 1, iteration = 120/496, loss = 4.35327
# epoch = 1, iteration = 130/496, loss = 4.98818
# epoch = 1, iteration = 140/496, loss = 4.18252
# epoch = 1, iteration = 150/496, loss = 3.89825
# epoch = 1, iteration = 160/496, loss = 3.08477
# epoch = 1, iteration = 170/496, loss = 3.95716
# epoch = 1, iteration = 180/496, loss = 2.94043
# epoch = 1, iteration = 190/496, loss = 3.66120
# epoch = 1, iteration = 200/496, loss = 4.13320
# epoch = 1, iteration = 210/496, loss = 3.61378
# epoch = 1, iteration = 220/496, loss = 3.29417
# epoch = 1, iteration = 230/496, loss = 3.77865
# epoch = 1, iteration = 240/496, loss = 2.69738
# epoch = 1, iteration = 250/496, loss = 3.93629
# epoch = 1, iteration = 260/496, loss = 3.15974
# epoch = 1, iteration = 270/496, loss = 2.89254
# epoch = 1, iteration = 280/496, loss = 3.58414
# epoch = 1, iteration = 290/496, loss = 3.76195
# epoch = 1, iteration = 300/496, loss = 3.73958
# epoch = 1, iteration = 310/496, loss = 3.12283
# epoch = 1, iteration = 320/496, loss = 3.05649
# epoch = 1, iteration = 330/496, loss = 3.08400
# epoch = 1, iteration = 340/496, loss = 2.47812
# epoch = 1, iteration = 350/496, loss = 2.51191
# epoch = 1, iteration = 360/496, loss = 2.56490
# epoch = 1, iteration = 370/496, loss = 4.77063
# epoch = 1, iteration = 380/496, loss = 2.96208
# epoch = 1, iteration = 390/496, loss = 3.84863
# epoch = 1, iteration = 400/496, loss = 3.75026
# epoch = 1, iteration = 410/496, loss = 2.64378
# epoch = 1, iteration = 420/496, loss = 2.21345
# epoch = 1, iteration = 430/496, loss = 2.31596
# epoch = 1, iteration = 440/496, loss = 3.86401
# epoch = 1, iteration = 450/496, loss = 1.98320
# epoch = 1, iteration = 460/496, loss = 3.32486
# epoch = 1, iteration = 470/496, loss = 3.49846
# epoch = 1, iteration = 480/496, loss = 3.47150
# epoch = 1, iteration = 490/496, loss = 2.51751
# Epoch finished ! Loss: 3.814151712860724
# Accuracy = [0.99, 0.5, 0.59, 0.45]
# Checkpoint 1 saved !
# Starting epoch 2/10.
# epoch = 2, iteration = 0/496, loss = 3.50552
# epoch = 2, iteration = 10/496, loss = 2.85201
# epoch = 2, iteration = 20/496, loss = 3.35660
# epoch = 2, iteration = 30/496, loss = 3.61925
# epoch = 2, iteration = 40/496, loss = 2.19227
# epoch = 2, iteration = 50/496, loss = 4.61905
# epoch = 9, iteration = 470/496, loss = 3.38349
# epoch = 9, iteration = 480/496, loss = 2.16018
# epoch = 9, iteration = 490/496, loss = 2.26355
# Epoch finished ! Loss: 2.6211403393384183
# Accuracy = [1.0, 0.54, 0.69, 0.53]
# Checkpoint 9 saved !
# Starting epoch 10/10.
# epoch = 10, iteration = 0/496, loss = 2.34538
# epoch = 10, iteration = 10/496, loss = 1.88311
# epoch = 10, iteration = 20/496, loss = 2.32532
# epoch = 10, iteration = 30/496, loss = 3.08420
# epoch = 10, iteration = 40/496, loss = 0.96667
# epoch = 10, iteration = 50/496, loss = 3.02631
# epoch = 10, iteration = 60/496, loss = 1.77000
# epoch = 10, iteration = 70/496, loss = 2.88313
# epoch = 10, iteration = 80/496, loss = 1.85519
# epoch = 10, iteration = 90/496, loss = 2.30339
# epoch = 10, iteration = 100/496, loss = 3.81197
# epoch = 10, iteration = 110/496, loss = 2.39722
# epoch = 10, iteration = 120/496, loss = 2.79850
# epoch = 10, iteration = 130/496, loss = 3.17449
# epoch = 10, iteration = 140/496, loss = 2.60073
# epoch = 10, iteration = 150/496, loss = 3.02482
# epoch = 10, iteration = 160/496, loss = 2.54983
# epoch = 10, iteration = 170/496, loss = 4.14550
# epoch = 10, iteration = 180/496, loss = 1.32634
# epoch = 10, iteration = 190/496, loss = 2.94881
# epoch = 10, iteration = 200/496, loss = 3.86247
# epoch = 10, iteration = 210/496, loss = 1.89738
# epoch = 10, iteration = 220/496, loss = 1.90344
# epoch = 10, iteration = 230/496, loss = 1.25166
# epoch = 10, iteration = 240/496, loss = 1.53528
# epoch = 10, iteration = 250/496, loss = 3.30493
# epoch = 10, iteration = 260/496, loss = 1.67891
# epoch = 10, iteration = 270/496, loss = 2.57737
# epoch = 10, iteration = 280/496, loss = 3.31374
# epoch = 10, iteration = 290/496, loss = 2.84506
# epoch = 10, iteration = 300/496, loss = 2.80315
# epoch = 10, iteration = 310/496, loss = 1.42195
# epoch = 10, iteration = 320/496, loss = 2.42674
# epoch = 10, iteration = 330/496, loss = 1.58611
# epoch = 10, iteration = 340/496, loss = 1.11684
# epoch = 10, iteration = 350/496, loss = 1.60302
# epoch = 10, iteration = 360/496, loss = 0.98506
# epoch = 10, iteration = 370/496, loss = 3.99465
# epoch = 10, iteration = 380/496, loss = 1.66585
# epoch = 10, iteration = 390/496, loss = 3.12012
# epoch = 10, iteration = 400/496, loss = 3.05728
# epoch = 10, iteration = 410/496, loss = 1.98886
# epoch = 10, iteration = 420/496, loss = 1.47389
# epoch = 10, iteration = 430/496, loss = 1.38481
# epoch = 10, iteration = 440/496, loss = 2.83609
# epoch = 10, iteration = 450/496, loss = 0.78092
# epoch = 10, iteration = 460/496, loss = 2.01682
# epoch = 10, iteration = 470/496, loss = 3.35036
# epoch = 10, iteration = 480/496, loss = 2.07925
# epoch = 10, iteration = 490/496, loss = 2.16026
# Epoch finished ! Loss: 2.501380178603259
# Accuracy = [1.0, 0.57, 0.7, 0.55]
# Checkpoint 10 saved !
# [1.0, 0.57, 0.73, 0.55]
