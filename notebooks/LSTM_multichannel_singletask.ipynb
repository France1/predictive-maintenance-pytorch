# %% [markdown]
# # LSTM multichannel single class classification

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from natsort import natsorted
import torch
import torch.nn as nn
from torch.nn import functional as F

from tensorboardX import SummaryWriter
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import sys
sys.path.insert(0, "../")
from data_preparation.prepare_data import import_data
from model import make_loaders, eval_batch

# %% [markdown]
# ### Data loading
# It is necessary to significanlty reduce the initial sequence length of 6000 for LSTM network. The most challenging target to classify is `1` for which the model is able to learn only for a sequence length of 50 combined with an attention model

# %%
data_dir = '<path-to-dataset>'

channels = ['CP', 'FS1', 'PS1', 'PS2', 'PS3', 'PS4', 'PS5', 'SE', 'VS1']

targets = [1]
gpu = False
in_len = 50

print('Preparing data')
data = import_data(data_dir, in_len)
train_loader, test_loader = make_loaders(data, channels, targets)
# Out:
# Preparing data

# %%
labels = []
for i in range(len(train_loader.dataset)):
    labels.append(train_loader.dataset.__getitem__(i)['label'].item())
    
set(labels)
# Out:
# {0, 1, 2, 3}

# %% [markdown]
# ### Model
# M.Luong et al, Effective Approaches to Attention-based Neural Machine Translation, 2015, arXiv:1508.04025
#
# Implementation from:
# https://github.com/prakashpandey9/Text-Classification-Pytorch
# https://github.com/spro/practical-pytorch/tree/master/seq2seq-translation

# %%
class Model(nn.Module):

    def __init__(self, input_dim, hidden_dim, output_dim=1, num_layers=2):
        super(Model, self).__init__()
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers

        # Define the LSTM layer
        self.lstm = nn.LSTM(self.input_dim, self.hidden_dim, self.num_layers)
        
        self.fc_block = nn.Sequential(
            nn.Linear(self.hidden_dim, self.hidden_dim),
            nn.BatchNorm1d(self.hidden_dim),
            nn.ReLU(inplace=True)
        ) 

        # Define the output layer
        self.linear = nn.Linear(self.hidden_dim, output_dim)
        
        self.concat = nn.Linear(self.hidden_dim * 2, self.hidden_dim)
        
#     def attention(self, lstm_output, hidden):
#     https://github.com/prakashpandey9/Text-Classification-Pytorch
        
#         hidden = hidden.squeeze(0)
#         lstm_output = lstm_output.permute(1,0,2)

#         score = torch.bmm(lstm_output, hidden.unsqueeze(2))
#         attn_weights = F.softmax(score, 1) # eq.7 
#         context = torch.bmm(lstm_output.transpose(1, 2), attn_weights).squeeze(2)
        
#         return context
    
    def attention(self, lstm_output, hidden):
        
        hidden = hidden.squeeze(0)
        lstm_output = lstm_output.permute(1,0,2)

        score = torch.bmm(lstm_output, hidden.unsqueeze(2))
        attn_weights = F.softmax(score, 1) # eq.7 
        context = torch.bmm(lstm_output.transpose(1, 2), attn_weights).squeeze(2)
        
        concat_input = torch.cat((hidden, context), 1)
        concat_output = torch.tanh(self.concat(concat_input)) # eq. 5
        
        return concat_output

    def forward(self, input):
        
        input = input.permute(2,0,1)
        lstm_out, (h,c) = self.lstm(input)
        
        out = self.attention(lstm_out, h[-1])
#         out = self.fc_block(lstm_out[-1])
        out = self.linear(out)
        
        return out

# %% [markdown]
# ### Train Model

# %%
model = Model(9, 20, output_dim=4, num_layers=1)
model.train()

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

epochs = 10
for epoch in range(epochs):
        
    print('Starting epoch {}/{}.'.format(epoch + 1, epochs))
    epoch_loss = 0
    correct = 0

    for i, sample_batch in enumerate(train_loader):
        
        sequences = sample_batch['sequence']
        true_labels = sample_batch['label'].squeeze()

        pred_labels = model(sequences)
        
        _, predicted = torch.max(pred_labels, 1)
        correct += (predicted == true_labels).float().sum()

        loss = criterion(pred_labels, true_labels)
        epoch_loss += loss.item()
        
        if i%10 == 0:
            print(f'epoch = {epoch+1:d}, iteration = {i:d}/{len(train_loader):d}, loss = {loss.item():.5f}')
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    print(f'Epoch {epoch+1} finished! Loss: {epoch_loss/i}. Accuracy: {correct.item()/len(train_loader.dataset)}')
# Out:
# Starting epoch 1/10.
# epoch = 1, iteration = 0/496, loss = 1.35050
# epoch = 1, iteration = 10/496, loss = 1.32014
# epoch = 1, iteration = 20/496, loss = 1.21037
# epoch = 1, iteration = 30/496, loss = 1.41937
# epoch = 1, iteration = 40/496, loss = 1.42623
# epoch = 1, iteration = 50/496, loss = 1.49742
# epoch = 1, iteration = 60/496, loss = 0.96758
# epoch = 1, iteration = 70/496, loss = 1.40615
# epoch = 1, iteration = 80/496, loss = 1.05095
# epoch = 1, iteration = 90/496, loss = 1.03292
# epoch = 1, iteration = 100/496, loss = 1.24753
# epoch = 1, iteration = 110/496, loss = 1.02006
# epoch = 1, iteration = 120/496, loss = 1.50157
# epoch = 1, iteration = 130/496, loss = 0.99592
# epoch = 1, iteration = 140/496, loss = 1.04547
# epoch = 1, iteration = 150/496, loss = 1.58921
# epoch = 1, iteration = 160/496, loss = 1.89748
# epoch = 1, iteration = 170/496, loss = 1.52127
# epoch = 1, iteration = 180/496, loss = 0.97000
# epoch = 1, iteration = 190/496, loss = 0.94962
# epoch = 1, iteration = 200/496, loss = 1.19137
# epoch = 1, iteration = 210/496, loss = 1.36940
# epoch = 1, iteration = 220/496, loss = 1.33593
# epoch = 1, iteration = 230/496, loss = 1.17665
# epoch = 1, iteration = 240/496, loss = 0.99083
# epoch = 1, iteration = 250/496, loss = 0.93642
# epoch = 1, iteration = 260/496, loss = 0.87266
# epoch = 1, iteration = 270/496, loss = 1.12592
# epoch = 1, iteration = 280/496, loss = 1.10721
# epoch = 1, iteration = 290/496, loss = 1.01354
# epoch = 1, iteration = 300/496, loss = 1.51156
# epoch = 1, iteration = 310/496, loss = 1.57166
# epoch = 1, iteration = 320/496, loss = 0.94936
# epoch = 1, iteration = 330/496, loss = 1.73412
# epoch = 1, iteration = 340/496, loss = 1.37024
# epoch = 1, iteration = 350/496, loss = 1.23729
# epoch = 1, iteration = 360/496, loss = 1.42292
# epoch = 1, iteration = 370/496, loss = 1.64905
# epoch = 1, iteration = 380/496, loss = 0.64445
# epoch = 1, iteration = 390/496, loss = 1.17536
# epoch = 1, iteration = 400/496, loss = 1.69498
# epoch = 1, iteration = 410/496, loss = 1.71452
# epoch = 1, iteration = 420/496, loss = 0.81641
# epoch = 1, iteration = 430/496, loss = 1.29562
# epoch = 1, iteration = 440/496, loss = 1.02579
# epoch = 1, iteration = 450/496, loss = 1.16357
# epoch = 1, iteration = 460/496, loss = 1.47864
# epoch = 1, iteration = 470/496, loss = 1.48697
# epoch = 1, iteration = 480/496, loss = 1.21520
# epoch = 1, iteration = 490/496, loss = 1.14139
# Epoch 1 finished! Loss: 1.2207006478550457. Accuracy: 0.5095766129032258
# Starting epoch 2/10.
# epoch = 2, iteration = 0/496, loss = 1.21092
# epoch = 2, iteration = 10/496, loss = 0.88701
# epoch = 2, iteration = 20/496, loss = 1.00809
# epoch = 2, iteration = 30/496, loss = 1.59874
# epoch = 2, iteration = 40/496, loss = 1.56359
# epoch = 2, iteration = 50/496, loss = 1.33475
# epoch = 2, iteration = 60/496, loss = 0.84591
# epoch = 2, iteration = 70/496, loss = 1.36273
# epoch = 2, iteration = 80/496, loss = 0.87425
# epoch = 2, iteration = 90/496, loss = 0.88911
# epoch = 2, iteration = 100/496, loss = 1.12451
# epoch = 2, iteration = 110/496, loss = 0.96752
# epoch = 2, iteration = 120/496, loss = 1.39653
# epoch = 2, iteration = 130/496, loss = 0.66278
# epoch = 2, iteration = 140/496, loss = 0.77029
# epoch = 2, iteration = 150/496, loss = 1.33579
# epoch = 2, iteration = 160/496, loss = 1.54237
# epoch = 2, iteration = 170/496, loss = 1.65473
# epoch = 2, iteration = 180/496, loss = 0.73553
# epoch = 2, iteration = 190/496, loss = 0.69482
# epoch = 2, iteration = 200/496, loss = 0.37744
# epoch = 2, iteration = 210/496, loss = 1.26002
# epoch = 2, iteration = 220/496, loss = 1.54870
# epoch = 2, iteration = 230/496, loss = 0.84013
# epoch = 2, iteration = 240/496, loss = 0.90189
# epoch = 2, iteration = 250/496, loss = 0.48205
# epoch = 2, iteration = 260/496, loss = 0.56748
# epoch = 2, iteration = 270/496, loss = 0.97666
# epoch = 2, iteration = 280/496, loss = 0.77106
# epoch = 2, iteration = 290/496, loss = 0.41597
# epoch = 2, iteration = 300/496, loss = 1.42660
# epoch = 2, iteration = 310/496, loss = 1.63512
# epoch = 2, iteration = 320/496, loss = 0.80466
# epoch = 2, iteration = 330/496, loss = 1.44320
# epoch = 2, iteration = 340/496, loss = 1.19776
# epoch = 2, iteration = 350/496, loss = 1.22042
# epoch = 2, iteration = 360/496, loss = 0.39289
# epoch = 2, iteration = 370/496, loss = 1.05811
# epoch = 2, iteration = 380/496, loss = 1.04730
# epoch = 2, iteration = 390/496, loss = 0.71603
# epoch = 2, iteration = 400/496, loss = 1.16480
# epoch = 2, iteration = 410/496, loss = 0.66732
# epoch = 2, iteration = 420/496, loss = 0.33515
# epoch = 2, iteration = 430/496, loss = 0.51304
# epoch = 2, iteration = 440/496, loss = 0.61096
# epoch = 2, iteration = 450/496, loss = 0.70565
# epoch = 2, iteration = 460/496, loss = 0.96218
# epoch = 2, iteration = 470/496, loss = 0.85001
# epoch = 2, iteration = 480/496, loss = 0.47484
# epoch = 2, iteration = 490/496, loss = 1.15993
# Epoch 2 finished! Loss: 0.9540790584051247. Accuracy: 0.6078629032258065
# Starting epoch 3/10.
# epoch = 3, iteration = 0/496, loss = 0.70306
# epoch = 3, iteration = 10/496, loss = 0.35797
# epoch = 3, iteration = 20/496, loss = 0.66557
# epoch = 3, iteration = 30/496, loss = 0.86662
# epoch = 3, iteration = 40/496, loss = 0.78369
# epoch = 3, iteration = 50/496, loss = 0.60273
# epoch = 3, iteration = 60/496, loss = 0.26876
# epoch = 3, iteration = 70/496, loss = 0.80992
# epoch = 3, iteration = 80/496, loss = 0.55416
# epoch = 3, iteration = 90/496, loss = 0.32707
# epoch = 3, iteration = 100/496, loss = 0.41177
# epoch = 3, iteration = 110/496, loss = 0.60780
# epoch = 3, iteration = 120/496, loss = 0.90184
# epoch = 3, iteration = 130/496, loss = 0.43755
# epoch = 3, iteration = 140/496, loss = 0.49264
# epoch = 3, iteration = 150/496, loss = 1.10692
# epoch = 3, iteration = 160/496, loss = 1.64742
# epoch = 3, iteration = 170/496, loss = 0.72229
# epoch = 3, iteration = 180/496, loss = 1.66259
# epoch = 3, iteration = 190/496, loss = 0.91535
# epoch = 3, iteration = 200/496, loss = 0.55372
# epoch = 3, iteration = 210/496, loss = 1.55298
# epoch = 3, iteration = 220/496, loss = 1.55070
# epoch = 3, iteration = 230/496, loss = 0.84724
# epoch = 3, iteration = 240/496, loss = 0.87842
# epoch = 3, iteration = 250/496, loss = 1.02869
# epoch = 3, iteration = 260/496, loss = 0.34732
# epoch = 3, iteration = 270/496, loss = 1.23025
# epoch = 3, iteration = 280/496, loss = 0.90851
# epoch = 3, iteration = 290/496, loss = 0.66520
# epoch = 3, iteration = 300/496, loss = 1.57000
# epoch = 3, iteration = 310/496, loss = 1.72562
# epoch = 3, iteration = 320/496, loss = 1.00680
# epoch = 3, iteration = 330/496, loss = 1.49800
# epoch = 3, iteration = 340/496, loss = 1.23275
# epoch = 3, iteration = 350/496, loss = 0.89079
# epoch = 3, iteration = 360/496, loss = 0.71655
# epoch = 3, iteration = 370/496, loss = 1.37275
# epoch = 3, iteration = 380/496, loss = 0.90312
# epoch = 3, iteration = 390/496, loss = 0.77880
# epoch = 3, iteration = 400/496, loss = 1.47803
# epoch = 3, iteration = 410/496, loss = 0.91370
# epoch = 3, iteration = 420/496, loss = 0.43679
# epoch = 3, iteration = 430/496, loss = 0.58464
# epoch = 3, iteration = 440/496, loss = 0.66914
# epoch = 3, iteration = 450/496, loss = 0.88224
# epoch = 3, iteration = 460/496, loss = 1.07276
# epoch = 3, iteration = 470/496, loss = 0.97863
# epoch = 3, iteration = 480/496, loss = 0.55399
# epoch = 3, iteration = 490/496, loss = 0.58076
# Epoch 3 finished! Loss: 0.8952783360324724. Accuracy: 0.6048387096774194
# Starting epoch 4/10.
# epoch = 4, iteration = 0/496, loss = 1.01445
# epoch = 4, iteration = 10/496, loss = 0.37630
# epoch = 4, iteration = 20/496, loss = 0.91158
# epoch = 4, iteration = 30/496, loss = 1.06408
# epoch = 4, iteration = 40/496, loss = 1.06907
# epoch = 4, iteration = 50/496, loss = 0.98028
# epoch = 4, iteration = 60/496, loss = 0.66201
# epoch = 4, iteration = 70/496, loss = 1.46674
# epoch = 4, iteration = 80/496, loss = 0.56625
# epoch = 4, iteration = 90/496, loss = 0.34099
# epoch = 4, iteration = 100/496, loss = 0.48340
# epoch = 4, iteration = 110/496, loss = 0.60296
# epoch = 4, iteration = 120/496, loss = 1.70807
# epoch = 4, iteration = 130/496, loss = 0.37158
# epoch = 4, iteration = 140/496, loss = 0.42596
# epoch = 4, iteration = 150/496, loss = 2.05518
# epoch = 4, iteration = 160/496, loss = 1.42407
# epoch = 4, iteration = 170/496, loss = 0.77790
# epoch = 4, iteration = 180/496, loss = 0.53787
# epoch = 4, iteration = 190/496, loss = 0.52401
# epoch = 4, iteration = 200/496, loss = 0.43310
# epoch = 4, iteration = 210/496, loss = 0.87773
# epoch = 4, iteration = 220/496, loss = 1.00469
# epoch = 4, iteration = 230/496, loss = 0.60913
# epoch = 4, iteration = 240/496, loss = 0.69908
# epoch = 4, iteration = 250/496, loss = 1.12664
# epoch = 4, iteration = 260/496, loss = 0.30037
# epoch = 4, iteration = 270/496, loss = 1.23457
# epoch = 4, iteration = 280/496, loss = 0.61078
# epoch = 4, iteration = 290/496, loss = 1.40244
# epoch = 4, iteration = 300/496, loss = 0.80328
# epoch = 4, iteration = 310/496, loss = 1.64157
# epoch = 4, iteration = 320/496, loss = 0.69980
# epoch = 4, iteration = 330/496, loss = 1.59572
# epoch = 4, iteration = 340/496, loss = 0.97596
# epoch = 4, iteration = 350/496, loss = 1.19923
# epoch = 4, iteration = 360/496, loss = 0.29026
# epoch = 4, iteration = 370/496, loss = 1.67818
# epoch = 4, iteration = 380/496, loss = 0.43088
# epoch = 4, iteration = 390/496, loss = 1.10962
# epoch = 4, iteration = 400/496, loss = 0.81793
# epoch = 4, iteration = 410/496, loss = 0.87746
# epoch = 4, iteration = 420/496, loss = 0.32398
# epoch = 4, iteration = 430/496, loss = 0.86967
# epoch = 4, iteration = 440/496, loss = 0.51289
# epoch = 4, iteration = 450/496, loss = 0.60804
# epoch = 4, iteration = 460/496, loss = 0.59642
# epoch = 4, iteration = 470/496, loss = 1.05303
# epoch = 4, iteration = 480/496, loss = 0.79174
# epoch = 4, iteration = 490/496, loss = 1.10694
# Epoch 4 finished! Loss: 0.8688147249546918. Accuracy: 0.6496975806451613
# Starting epoch 5/10.
# epoch = 5, iteration = 0/496, loss = 0.97129
# epoch = 5, iteration = 10/496, loss = 0.31779
# epoch = 5, iteration = 20/496, loss = 0.73089
# epoch = 5, iteration = 30/496, loss = 1.15663
# epoch = 5, iteration = 40/496, loss = 1.08884
# epoch = 5, iteration = 50/496, loss = 0.66093
# epoch = 5, iteration = 60/496, loss = 0.40973
# epoch = 5, iteration = 70/496, loss = 0.72083
# epoch = 5, iteration = 80/496, loss = 0.63593
# epoch = 5, iteration = 90/496, loss = 0.86577
# epoch = 5, iteration = 100/496, loss = 0.98851
# epoch = 5, iteration = 110/496, loss = 0.67885
# epoch = 5, iteration = 120/496, loss = 1.18577
# epoch = 5, iteration = 130/496, loss = 0.35225
# epoch = 5, iteration = 140/496, loss = 0.43293
# epoch = 5, iteration = 150/496, loss = 1.27796
# epoch = 5, iteration = 160/496, loss = 0.80133
# epoch = 5, iteration = 170/496, loss = 0.79551
# epoch = 5, iteration = 180/496, loss = 0.88800
# epoch = 5, iteration = 190/496, loss = 0.56740
# epoch = 5, iteration = 200/496, loss = 0.46150
# epoch = 5, iteration = 210/496, loss = 1.23686
# epoch = 5, iteration = 220/496, loss = 1.19557
# epoch = 5, iteration = 230/496, loss = 0.65416
# epoch = 5, iteration = 240/496, loss = 0.76819
# epoch = 5, iteration = 250/496, loss = 0.44214
# epoch = 5, iteration = 260/496, loss = 0.27656
# epoch = 5, iteration = 270/496, loss = 0.87073
# epoch = 5, iteration = 280/496, loss = 0.72496
# epoch = 5, iteration = 290/496, loss = 0.37820
# epoch = 5, iteration = 300/496, loss = 1.31716
# epoch = 5, iteration = 310/496, loss = 0.74049
# epoch = 5, iteration = 320/496, loss = 0.69532
# epoch = 5, iteration = 330/496, loss = 1.35648
# epoch = 5, iteration = 340/496, loss = 1.14986
# epoch = 5, iteration = 350/496, loss = 1.34654
# epoch = 5, iteration = 360/496, loss = 0.43593
# epoch = 5, iteration = 370/496, loss = 0.92225
# epoch = 5, iteration = 380/496, loss = 0.30330
# epoch = 5, iteration = 390/496, loss = 0.66853
# epoch = 5, iteration = 400/496, loss = 1.41965
# epoch = 5, iteration = 410/496, loss = 0.61431
# epoch = 5, iteration = 420/496, loss = 0.36660
# epoch = 5, iteration = 430/496, loss = 1.14337
# epoch = 5, iteration = 440/496, loss = 0.54734
# epoch = 5, iteration = 450/496, loss = 1.07257
# epoch = 5, iteration = 460/496, loss = 0.75407
# epoch = 5, iteration = 470/496, loss = 1.18010
# epoch = 5, iteration = 480/496, loss = 0.46205
# epoch = 5, iteration = 490/496, loss = 0.45430
# Epoch 5 finished! Loss: 0.7866942011647754. Accuracy: 0.6633064516129032
# Starting epoch 6/10.
# epoch = 6, iteration = 0/496, loss = 0.64530
# epoch = 6, iteration = 10/496, loss = 0.34436
# epoch = 6, iteration = 20/496, loss = 0.66744
# epoch = 6, iteration = 30/496, loss = 0.89150
# epoch = 6, iteration = 40/496, loss = 0.81007
# epoch = 6, iteration = 50/496, loss = 0.63250
# epoch = 6, iteration = 60/496, loss = 0.28104
# epoch = 6, iteration = 70/496, loss = 0.77011
# epoch = 6, iteration = 80/496, loss = 0.55844
# epoch = 6, iteration = 90/496, loss = 1.04956
# epoch = 6, iteration = 100/496, loss = 0.51637
# epoch = 6, iteration = 110/496, loss = 0.61235
# epoch = 6, iteration = 120/496, loss = 1.45312
# epoch = 6, iteration = 130/496, loss = 0.38812
# epoch = 6, iteration = 140/496, loss = 0.42651
# epoch = 6, iteration = 150/496, loss = 1.90573
# epoch = 6, iteration = 160/496, loss = 0.74934
# epoch = 6, iteration = 170/496, loss = 0.74493
# epoch = 6, iteration = 180/496, loss = 0.54323
# epoch = 6, iteration = 190/496, loss = 0.53950
# epoch = 6, iteration = 200/496, loss = 0.39840
# epoch = 6, iteration = 210/496, loss = 0.87919
# epoch = 6, iteration = 220/496, loss = 1.00391
# epoch = 6, iteration = 230/496, loss = 0.56541
# epoch = 6, iteration = 240/496, loss = 0.68505
# epoch = 6, iteration = 250/496, loss = 0.48632
# epoch = 6, iteration = 260/496, loss = 0.29879
# epoch = 6, iteration = 270/496, loss = 0.78509
# epoch = 6, iteration = 280/496, loss = 0.61886
# epoch = 6, iteration = 290/496, loss = 0.39287
# epoch = 6, iteration = 300/496, loss = 0.84066
# epoch = 6, iteration = 310/496, loss = 0.72901
# epoch = 6, iteration = 320/496, loss = 0.68533
# epoch = 6, iteration = 330/496, loss = 2.94558
# epoch = 6, iteration = 340/496, loss = 3.22771
# epoch = 6, iteration = 350/496, loss = 1.25674
# epoch = 6, iteration = 360/496, loss = 1.34399
# epoch = 6, iteration = 370/496, loss = 1.25333
# epoch = 6, iteration = 380/496, loss = 0.58881
# epoch = 6, iteration = 390/496, loss = 1.11965
# epoch = 6, iteration = 400/496, loss = 1.76290
# epoch = 6, iteration = 410/496, loss = 1.65852
# epoch = 6, iteration = 420/496, loss = 0.94833
# epoch = 6, iteration = 430/496, loss = 1.16623
# epoch = 6, iteration = 440/496, loss = 0.95699
# epoch = 6, iteration = 450/496, loss = 0.85712
# epoch = 6, iteration = 460/496, loss = 1.36272
# epoch = 6, iteration = 470/496, loss = 1.48051
# epoch = 6, iteration = 480/496, loss = 1.08317
# epoch = 6, iteration = 490/496, loss = 1.06341
# Epoch 6 finished! Loss: 0.9086064572888192. Accuracy: 0.6063508064516129
# Starting epoch 7/10.
# epoch = 7, iteration = 0/496, loss = 1.23401
# epoch = 7, iteration = 10/496, loss = 0.88017
# epoch = 7, iteration = 20/496, loss = 0.84003
# epoch = 7, iteration = 30/496, loss = 1.41872
# epoch = 7, iteration = 40/496, loss = 1.29734
# epoch = 7, iteration = 50/496, loss = 0.86817
# epoch = 7, iteration = 60/496, loss = 1.40995
# epoch = 7, iteration = 70/496, loss = 1.04500
# epoch = 7, iteration = 80/496, loss = 0.59349
# epoch = 7, iteration = 90/496, loss = 0.80266
# epoch = 7, iteration = 100/496, loss = 0.90122
# epoch = 7, iteration = 110/496, loss = 0.77252
# epoch = 7, iteration = 120/496, loss = 1.30310
# epoch = 7, iteration = 130/496, loss = 0.61699
# epoch = 7, iteration = 140/496, loss = 0.51912
# epoch = 7, iteration = 150/496, loss = 0.99097
# epoch = 7, iteration = 160/496, loss = 0.98987
# epoch = 7, iteration = 170/496, loss = 1.30061
# epoch = 7, iteration = 180/496, loss = 0.67156
# epoch = 7, iteration = 190/496, loss = 0.65183
# epoch = 7, iteration = 200/496, loss = 0.43759
# epoch = 7, iteration = 210/496, loss = 1.07228
# epoch = 7, iteration = 220/496, loss = 1.03873
# epoch = 7, iteration = 230/496, loss = 0.84464
# epoch = 7, iteration = 240/496, loss = 0.59686
# epoch = 7, iteration = 250/496, loss = 0.39078
# epoch = 7, iteration = 260/496, loss = 0.26052
# epoch = 7, iteration = 270/496, loss = 1.11618
# epoch = 7, iteration = 280/496, loss = 0.80998
# epoch = 7, iteration = 290/496, loss = 0.29615
# epoch = 7, iteration = 300/496, loss = 1.07102
# epoch = 7, iteration = 310/496, loss = 0.71286
# epoch = 7, iteration = 320/496, loss = 0.61506
# epoch = 7, iteration = 330/496, loss = 1.40407
# epoch = 7, iteration = 340/496, loss = 1.05837
# epoch = 7, iteration = 350/496, loss = 0.85628
# epoch = 7, iteration = 360/496, loss = 0.53536
# epoch = 7, iteration = 370/496, loss = 1.79285
# epoch = 7, iteration = 380/496, loss = 0.36088
# epoch = 7, iteration = 390/496, loss = 0.67576
# epoch = 7, iteration = 400/496, loss = 1.12810
# epoch = 7, iteration = 410/496, loss = 1.34879
# epoch = 7, iteration = 420/496, loss = 0.31961
# epoch = 7, iteration = 430/496, loss = 0.49232
# epoch = 7, iteration = 440/496, loss = 0.52003
# epoch = 7, iteration = 450/496, loss = 0.52605
# epoch = 7, iteration = 460/496, loss = 0.69232
# epoch = 7, iteration = 470/496, loss = 0.97181
# epoch = 7, iteration = 480/496, loss = 0.43766
# epoch = 7, iteration = 490/496, loss = 0.92625
# Epoch 7 finished! Loss: 0.8030658328774. Accuracy: 0.6421370967741935
# Starting epoch 8/10.
# epoch = 8, iteration = 0/496, loss = 0.88469
# epoch = 8, iteration = 10/496, loss = 0.38051
# epoch = 8, iteration = 20/496, loss = 0.48067
# epoch = 8, iteration = 30/496, loss = 0.70470
# epoch = 8, iteration = 40/496, loss = 0.58672
# epoch = 8, iteration = 50/496, loss = 0.77218
# epoch = 8, iteration = 60/496, loss = 0.22882
# epoch = 8, iteration = 70/496, loss = 0.54990
# epoch = 8, iteration = 80/496, loss = 0.36306
# epoch = 8, iteration = 90/496, loss = 0.46654
# epoch = 8, iteration = 100/496, loss = 0.43078
# epoch = 8, iteration = 110/496, loss = 0.55111
# epoch = 8, iteration = 120/496, loss = 0.62793
# epoch = 8, iteration = 130/496, loss = 0.44105
# epoch = 8, iteration = 140/496, loss = 0.28774
# epoch = 8, iteration = 150/496, loss = 1.14856
# epoch = 8, iteration = 160/496, loss = 0.76617
# epoch = 8, iteration = 170/496, loss = 0.77149
# epoch = 8, iteration = 180/496, loss = 0.25360
# epoch = 8, iteration = 190/496, loss = 0.29099
# epoch = 8, iteration = 200/496, loss = 0.27516
# epoch = 8, iteration = 210/496, loss = 0.56210
# epoch = 8, iteration = 220/496, loss = 0.58286
# epoch = 8, iteration = 230/496, loss = 0.56069
# epoch = 8, iteration = 240/496, loss = 0.52097
# epoch = 8, iteration = 250/496, loss = 0.83558
# epoch = 8, iteration = 260/496, loss = 0.40492
# epoch = 8, iteration = 270/496, loss = 1.16488
# epoch = 8, iteration = 280/496, loss = 0.37291
# epoch = 8, iteration = 290/496, loss = 0.24374
# epoch = 8, iteration = 300/496, loss = 0.81194
# epoch = 8, iteration = 310/496, loss = 0.66681
# epoch = 8, iteration = 320/496, loss = 0.46430
# epoch = 8, iteration = 330/496, loss = 1.31598
# epoch = 8, iteration = 340/496, loss = 0.75853
# epoch = 8, iteration = 350/496, loss = 0.41200
# epoch = 8, iteration = 360/496, loss = 0.35726
# epoch = 8, iteration = 370/496, loss = 0.77197
# epoch = 8, iteration = 380/496, loss = 0.35754
# epoch = 8, iteration = 390/496, loss = 0.34842
# epoch = 8, iteration = 400/496, loss = 0.58810
# epoch = 8, iteration = 410/496, loss = 0.55977
# epoch = 8, iteration = 420/496, loss = 0.30854
# epoch = 8, iteration = 430/496, loss = 0.49129
# epoch = 8, iteration = 440/496, loss = 0.43717
# epoch = 8, iteration = 450/496, loss = 0.91142
# epoch = 8, iteration = 460/496, loss = 0.84647
# epoch = 8, iteration = 470/496, loss = 0.49568
# epoch = 8, iteration = 480/496, loss = 0.37411
# epoch = 8, iteration = 490/496, loss = 0.35984
# Epoch 8 finished! Loss: 0.5790627498593596. Accuracy: 0.7444556451612904
# Starting epoch 9/10.
# epoch = 9, iteration = 0/496, loss = 0.50962
# epoch = 9, iteration = 10/496, loss = 0.29636
# epoch = 9, iteration = 20/496, loss = 0.29994
# epoch = 9, iteration = 30/496, loss = 0.96605
# epoch = 9, iteration = 40/496, loss = 0.44815
# epoch = 9, iteration = 50/496, loss = 0.50159
# epoch = 9, iteration = 60/496, loss = 0.08065
# epoch = 9, iteration = 70/496, loss = 0.78022
# epoch = 9, iteration = 80/496, loss = 0.21992
# epoch = 9, iteration = 90/496, loss = 0.17571
# epoch = 9, iteration = 100/496, loss = 0.31942
# epoch = 9, iteration = 110/496, loss = 0.17203
# epoch = 9, iteration = 120/496, loss = 0.40600
# epoch = 9, iteration = 130/496, loss = 0.31823
# epoch = 9, iteration = 140/496, loss = 0.24298
# epoch = 9, iteration = 150/496, loss = 1.14598
# epoch = 9, iteration = 160/496, loss = 0.67172
# epoch = 9, iteration = 170/496, loss = 0.91626
# epoch = 9, iteration = 180/496, loss = 0.10397
# epoch = 9, iteration = 190/496, loss = 0.19929
# epoch = 9, iteration = 200/496, loss = 0.24841
# epoch = 9, iteration = 210/496, loss = 0.43193
# epoch = 9, iteration = 220/496, loss = 0.39899
# epoch = 9, iteration = 230/496, loss = 0.69405
# epoch = 9, iteration = 240/496, loss = 0.71992
# epoch = 9, iteration = 250/496, loss = 0.79140
# epoch = 9, iteration = 260/496, loss = 0.17328
# epoch = 9, iteration = 270/496, loss = 0.47403
# epoch = 9, iteration = 280/496, loss = 0.22641
# epoch = 9, iteration = 290/496, loss = 0.13802
# epoch = 9, iteration = 300/496, loss = 0.62723
# epoch = 9, iteration = 310/496, loss = 0.61367
# epoch = 9, iteration = 320/496, loss = 0.36701
# epoch = 9, iteration = 330/496, loss = 0.96483
# epoch = 9, iteration = 340/496, loss = 0.77911
# epoch = 9, iteration = 350/496, loss = 0.28398
# epoch = 9, iteration = 360/496, loss = 0.34182
# epoch = 9, iteration = 370/496, loss = 0.59915
# epoch = 9, iteration = 380/496, loss = 0.17589
# epoch = 9, iteration = 390/496, loss = 0.25954
# epoch = 9, iteration = 400/496, loss = 0.39363
# epoch = 9, iteration = 410/496, loss = 0.45307
# epoch = 9, iteration = 420/496, loss = 0.19273
# epoch = 9, iteration = 430/496, loss = 0.35748
# epoch = 9, iteration = 440/496, loss = 0.27138
# epoch = 9, iteration = 450/496, loss = 0.22234
# epoch = 9, iteration = 460/496, loss = 0.44436
# epoch = 9, iteration = 470/496, loss = 0.35266
# epoch = 9, iteration = 480/496, loss = 0.28205
# epoch = 9, iteration = 490/496, loss = 0.33277
# Epoch 9 finished! Loss: 0.4617163194287004. Accuracy: 0.8356854838709677
# Starting epoch 10/10.
# epoch = 10, iteration = 0/496, loss = 0.36441
# epoch = 10, iteration = 10/496, loss = 0.30880
# epoch = 10, iteration = 20/496, loss = 0.49172
# epoch = 10, iteration = 30/496, loss = 0.62069
# epoch = 10, iteration = 40/496, loss = 0.38146
# epoch = 10, iteration = 50/496, loss = 0.36267
# epoch = 10, iteration = 60/496, loss = 0.06593
# epoch = 10, iteration = 70/496, loss = 0.89239
# epoch = 10, iteration = 80/496, loss = 0.13056
# epoch = 10, iteration = 90/496, loss = 0.10117
# epoch = 10, iteration = 100/496, loss = 0.20601
# epoch = 10, iteration = 110/496, loss = 0.11928
# epoch = 10, iteration = 120/496, loss = 0.29510
# epoch = 10, iteration = 130/496, loss = 0.22391
# epoch = 10, iteration = 140/496, loss = 0.14291
# epoch = 10, iteration = 150/496, loss = 0.93777
# epoch = 10, iteration = 160/496, loss = 0.40233
# epoch = 10, iteration = 170/496, loss = 0.75419
# epoch = 10, iteration = 180/496, loss = 0.07545
# epoch = 10, iteration = 190/496, loss = 0.11322
# epoch = 10, iteration = 200/496, loss = 0.13163
# epoch = 10, iteration = 210/496, loss = 0.31290
# epoch = 10, iteration = 220/496, loss = 0.22844
# epoch = 10, iteration = 230/496, loss = 0.94772
# epoch = 10, iteration = 240/496, loss = 0.12703
# epoch = 10, iteration = 250/496, loss = 0.18986
# epoch = 10, iteration = 260/496, loss = 0.09052
# epoch = 10, iteration = 270/496, loss = 0.24158
# epoch = 10, iteration = 280/496, loss = 0.12001
# epoch = 10, iteration = 290/496, loss = 0.26571
# epoch = 10, iteration = 300/496, loss = 0.72315
# epoch = 10, iteration = 310/496, loss = 0.30157
# epoch = 10, iteration = 320/496, loss = 0.23605
# epoch = 10, iteration = 330/496, loss = 0.23978
# epoch = 10, iteration = 340/496, loss = 1.09675
# epoch = 10, iteration = 350/496, loss = 0.12430
# epoch = 10, iteration = 360/496, loss = 0.13526
# epoch = 10, iteration = 370/496, loss = 0.48237
# epoch = 10, iteration = 380/496, loss = 0.34298
# epoch = 10, iteration = 390/496, loss = 0.11444
# epoch = 10, iteration = 400/496, loss = 0.15195
# epoch = 10, iteration = 410/496, loss = 0.28965
# epoch = 10, iteration = 420/496, loss = 0.18493
# epoch = 10, iteration = 430/496, loss = 0.15270
# epoch = 10, iteration = 440/496, loss = 0.17888
# epoch = 10, iteration = 450/496, loss = 0.08875
# epoch = 10, iteration = 460/496, loss = 0.14053
# epoch = 10, iteration = 470/496, loss = 0.20554
# epoch = 10, iteration = 480/496, loss = 0.17731
# epoch = 10, iteration = 490/496, loss = 0.19012
# Epoch 10 finished! Loss: 0.34057541742469327. Accuracy: 0.8991935483870968

# %% [markdown]
# ### Evaluate Model

# %%
model.eval()

true_labels = []
pred_labels = []

for i, sample_batch in enumerate(test_loader):
    
    sequences = sample_batch['sequence']
    true_batch = sample_batch['label']
    
    outputs = model(sequences)
    _, pred_batch = torch.max(outputs, 1)
    
    true_labels.append(true_batch.detach().numpy())
    pred_labels.append(pred_batch.detach().numpy())

true_labels = np.concatenate(true_labels).squeeze()
pred_labels = np.concatenate(pred_labels)

# %%
acc = (true_labels==pred_labels).sum()/len(true_labels)
cm = confusion_matrix(true_labels, pred_labels)
cr = classification_report(true_labels, pred_labels)
print(acc)
print(cm)
print(cr)
# Out:
# 0.9045454545454545
# [[ 34   2   0   0]
#  [  0  32   4   0]
#  [  0   0  20  15]
#  [  0   0   0 113]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97        36
#            1       0.94      0.89      0.91        36
#            2       0.83      0.57      0.68        35
#            3       0.88      1.00      0.94       113
#
#     accuracy                           0.90       220
#    macro avg       0.91      0.85      0.88       220
# weighted avg       0.90      0.90      0.90       220

# %% [markdown]
# ### Attention model testing

# %%
seq_size = 30
input_size = 10
hidden_size = 15
batch_size = 4
output_size = 3

lstm = nn.LSTM(input_size, hidden_size, num_layers=2) 
concat = nn.Linear(hidden_size * 2, hidden_size)
logits = nn.Linear(hidden_size, output_size)

# %%
x = torch.randn(seq_size, batch_size, input_size) 
out, (h,c) = lstm(x)

# %%
hidden = h[-1].squeeze(0)
output = out.permute(1,0,2)

print(hidden.size())
print(output.size())

score = torch.bmm(output, hidden.unsqueeze(2))
attn_weights = F.softmax(score, 1) # eq.7 
context = torch.bmm(output.transpose(1, 2), attn_weights).squeeze(2)
# Out:
# torch.Size([4, 15])
# torch.Size([4, 30, 15])

# %%
concat_input = torch.cat((hidden, context), 1)
concat_output = torch.tanh(concat(concat_input)) # eq. 5
output = logits(concat_output) # eq. 6

# %%
out.size()
# Out:
# torch.Size([30, 4, 15])

# %%
hidden.unsqueeze(2).size()
# Out:
# torch.Size([4, 15, 1])

# %%
out.size()
# Out:
# torch.Size([30, 4, 15])
